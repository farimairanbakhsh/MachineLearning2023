# %% [markdown]
# <a href="https://colab.research.google.com/github/farimairanbakhsh/MachineLearning2023/blob/main/HW1/AI4021_HW1_2_Python_Tutorial_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Problem 1:** Create a NumPy array of 20 random integers between 1 and 100. Calculate the mean, median, and standard deviation of the array.

# %%
import numpy as np

arr = np.random.randint(1,100,20)
print(arr)

print(np.mean(arr))
print(np.median(arr))
print(np.std(arr))
# Out:
# [54 47 61  1 81 57 75 37 88 76 97 68 73 50 93  8  5 74 70 56]
# 58.55
# 64.5
# 27.130195354991457

# %% [markdown]
# **Problem 2:** Create a Pandas DataFrame with three columns - 'Name', 'Age', and 'City' - and at least five rows of data. Perform a basic data exploration by displaying the first 3 rows, the last 2 rows, and a summary of statistics for the 'Age' column.

# %%
import pandas as pd

data = {
    "Name" : ["Farima" , "Zahra", "Dorsa", "Saeed", "Navid"],
    "Age" : [23 , 20, 19, 30, 47],
    "City" : ["Tehran", "Esfehan", "Sari", "Ardebil", "Mazandaran"]
}

df = pd.DataFrame(data)

print(df.head(3))
print(df.tail(2))

df.describe()
# Out:
#      Name  Age     City
# 0  Farima   23   Tehran
# 1   Zahra   20  Esfehan
# 2   Dorsa   19     Sari
#     Name  Age        City
# 3  Saeed   30     Ardebil
# 4  Navid   47  Mazandaran
#              Age
# count   5.000000
# mean   27.800000
# std    11.562872
# min    19.000000
# 25%    20.000000
# 50%    23.000000
# 75%    30.000000
# max    47.000000

# %% [markdown]
# **Problem 3:** Create a bar chart using Matplotlib to visualize the following data: Monthly sales for a store (January to May). Use appropriate labels and titles for the chart.

# %%
#3
import matplotlib.pyplot as plt

labels = ["january", "february", "march", "april", "may"]
values = [100, 200, 170, 140, 175]
colors = ['skyblue', 'lightcoral', 'lightgreen', 'lightsalmon', 'lightpink']

plt.title("salary", size=15)
plt.xlabel("months", size=13)
plt.ylabel("monthly sales", size=13)
plt.xticks(rotation=45)
plt.bar(labels, values, color=colors, width=0.6, align='center')

for i, v in enumerate(values):
    plt.text(i, v + 10, str(v), ha='center', va='bottom', fontsize=10)

plt.show()

# %% [markdown]
# **Problem 4:** Create two NumPy arrays, 'arr1' and 'arr2', both of size 5x5 with random integer values. Perform element-wise addition, subtraction, multiplication, and division between the two arrays.

# %%
arr1 = np.random.randint((5,5))
arr2 = np.random.randint((5,5))

print("element-wise addition: ")
print(arr1 + arr2)
print("subtraction: ")
print(arr1 - arr2)
print("multiplication: ")
print(arr1 * arr2)
print("division: ")
print(arr1 / arr2)
# Out:
# element-wise addition:
# [6 2]
# subtraction:
# [2 2]
# multiplication:
# [8 0]
# division:
# [ 2. inf]
# <ipython-input-4-af61d988f98f>:11: RuntimeWarning: divide by zero encountered in divide
#   print(arr1 / arr2)

# %% [markdown]
# **Problem 5:** Given a Pandas DataFrame with information about employees, filter and display only the employees who are older than 30 years.

# %%
#5
age = df[df["Age"]>30]
print(age)
# Out:
#     Name  Age        City
# 4  Navid   47  Mazandaran

# %% [markdown]
# **Problem 6:** Create a scatter plot using Matplotlib to visualize a dataset of 100 random (x, y) coordinates. Label the axes appropriately and give the plot a title.

# %%
#6

x = np.random.rand(100)
y = np.random.rand(100)

plt.scatter(x,y, color="pink", marker='*', s=75)
plt.title("Random Plot", size=15 )
plt.xlabel("X", size = 12)
plt.ylabel("Y", size = 12)
plt.show()

# %% [markdown]
# **Problem 7:** Create two NumPy matrices, 'matrix1' (2x3) and 'matrix2' (3x4), with random values. Perform matrix multiplication between the two matrices.

# %%
matrix1 = np.random.rand(2,3)
matrix2 = np.random.rand(3,4)

print(np.dot(matrix1, matrix2))
# Out:
# [[0.01374249 0.88967378 0.69606517 0.8995636 ]
#  [0.02266724 0.68975956 0.53309103 0.57780975]]

# %% [markdown]
# **Problem 8:** Given a Pandas DataFrame containing sales data, calculate and display the total sales for each product category.

# %%
data = {
    "product" : ['sib', 'moz', 'reyhoon', 'sibzamini', 'shivid'],
    "category" : ['miveh', 'miveh', 'sabzijat', 'seifijat', 'sabzijat'],
    "sales" : [250, 300, 126, 360, 70]
}

sales_data = pd.DataFrame(data)
total_sales = sales_data.groupby('category')['sales'].sum()

print(total_sales)
# Out:
# category
# miveh       550
# sabzijat    196
# seifijat    360
# Name: sales, dtype: int64

# %% [markdown]
# **Problem 9:** Create a line chart using Matplotlib to visualize the population growth of a city over 10 years. Label the axes and provide a title.

# %%
labels = [2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]
values = [37944551, 38253768, 38586706, 38904296, 39149186, 39337785, 39437463, 39437610, 39499738, 39237836]

colors = ['aquamarine', 'honeydew', 'ivory', 'aliceblue', 'lightpink', 'peachpuff', 'snow', 'linen', 'lemonchiffon', 'lavender']

plt.clf

plt.figure(figsize=(10, 6))
plt.bar(labels, values, color=colors, width=0.7, align='center')
plt.title("population growth of california", color='mediumvioletred', size=16)
plt.xlabel("year", color='mediumvioletred', size=13)
plt.ylabel("population", color='mediumvioletred', size=13)
plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()

# %% [markdown]
# **Problem 10:** Given a Pandas DataFrame containing information about students, add a new column 'Grade' based on the following criteria:
# * If 'Score' >= 90, Grade is 'A'
# * If 'Score' >= 80, Grade is 'B'
# * If 'Score' >= 70, Grade is 'C'
# * If 'Score' < 70, Grade is 'D'

# %%
df["score"] = [97, 74, 36, 55, 80]

def nomre(score):
  if score >= 90:
    return 'A'
  if score >= 80:
    return 'B'
  if score >= 70:
    return 'C'
  if score < 70:
    return 'D'

gr = df["score"].apply(nomre)

print(gr)
# Out:
# 0    A
# 1    C
# 2    D
# 3    D
# 4    B
# Name: score, dtype: object

# %% [markdown]
# **Problem 11:** You are given a dataset containing monthly sales data for three products (A, B, and C) over a two-year period. Your task is to perform various data analysis tasks using NumPy, Pandas, and Matplotlib.
#
#
# *   Dataset:
#
# ```
# import pandas as pd
#
# data = {
#     'Month': pd.date_range(start='2021-01-01', periods=24, freq='M'),
#     'Product A Sales': [500, 480, 600, 750, 900, 850, 920, 1100, 1300, 1350, 1500, 1450, 1550, 1600, 1650, 1600, 1500, 1400, 1600, 1700, 1800, 1750, 1850, 1900],
#     'Product B Sales': [300, 320, 400, 450, 500, 580, 700, 750, 820, 900, 950, 980, 1050, 1100, 1150, 1200, 1250, 1300, 1350, 1400, 1500, 1600, 1550, 1700],
#     'Product C Sales': [200, 210, 250, 280, 320, 350, 380, 400, 420, 440, 460, 480, 500, 520, 540, 560, 580, 600, 620, 640, 660, 680, 700, 720]
# }
#
# sales_df = pd.DataFrame(data)
# ```
# *  Tasks:
# 1. Calculate and display the total sales for each product over the two-year period.
#
# 2. Calculate and display the average monthly sales for each product.
#
# 3. Find the month with the highest sales for each product, and display the product and the sales value for that month.
#
# 4. Calculate and display the percentage change in sales for each product from January to December in the second year (2022).
#
# 5. Create a line chart using Matplotlib to visualize the monthly sales data for each product over the two-year period. Label the axes and provide a title for the chart.
#
# 6. Calculate the correlation between Product A and Product B sales. Is there a strong correlation between these two products? Display the correlation coefficient.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

data = {
    'Month': pd.date_range(start='2021-01-01', periods=24, freq='M'),
    'Product A Sales': [500, 480, 600, 750, 900, 850, 920, 1100, 1300, 1350, 1500, 1450, 1550, 1600, 1650, 1600, 1500, 1400, 1600, 1700, 1800, 1750, 1850, 1900],
    'Product B Sales': [300, 320, 400, 450, 500, 580, 700, 750, 820, 900, 950, 980, 1050, 1100, 1150, 1200, 1250, 1300, 1350, 1400, 1500, 1600, 1550, 1700],
    'Product C Sales': [200, 210, 250, 280, 320, 350, 380, 400, 420, 440, 460, 480, 500, 520, 540, 560, 580, 600, 620, 640, 660, 680, 700, 720]
}

sales_df = pd.DataFrame(data)

# %%
print("total sales for each product: ")
print(sales_df.sum())

#2
print("\naverage monthly sales:")
print(sales_df.mean())

#3
max_a = sales_df['Product A Sales'].idxmax()
max_b = sales_df['Product B Sales'].idxmax()
max_c = sales_df['Product C Sales'].idxmax()

month_a = sales_df.loc[max_a, 'Month']
sales_a = sales_df.loc[max_a, 'Product A Sales']
month_b = sales_df.loc[max_b, 'Month']
sales_b = sales_df.loc[max_b, 'Product B Sales']
month_c = sales_df.loc[max_c, 'Month']
sales_c = sales_df.loc[max_c, 'Product C Sales']

print("\nSales A:", sales_a, "month", month_a)
print("Sales B:", sales_b, "month", month_b)
print("Sales C:", sales_c, "month", month_c)

#4
sales_2022 = sales_df[(sales_df['Month'] >= '2022-01-01') & (sales_df['Month'] <= '2022-12-31')]
change_percent_a = ((sales_2022['Product A Sales'].iloc[-1] - sales_2022['Product A Sales'].iloc[0]) / sales_2022['Product A Sales'].iloc[0]) * 100
change_percent_b = ((sales_2022['Product B Sales'].iloc[-1] - sales_2022['Product B Sales'].iloc[0]) / sales_2022['Product B Sales'].iloc[0]) * 100
change_percent_c = ((sales_2022['Product C Sales'].iloc[-1] - sales_2022['Product C Sales'].iloc[0]) / sales_2022['Product C Sales'].iloc[0]) * 100

print("\nchange percent of product A is", change_percent_a, "%")
print("change percent of product B is", change_percent_b, "%")
print("change percent of product C is", change_percent_c, "%")

#5
plt.figure(figsize=(12,6))
plt.bar(sales_df['Month'],sales_df['Product A Sales'], label='Product A sales')
plt.bar(sales_df['Month'],sales_df['Product B Sales'], label='Product B Sales')
plt.bar(sales_df['Month'],sales_df['Product C Sales'], label='Product C Sales')

plt.xlabel("Months")
plt.ylabel("Sales")
plt.title("Sales for each products in 2 years")
plt.xticks(rotation = 45)

plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.legend()

#6
correlation = sales_df['Product A Sales'].corr(sales_df['Product B Sales'])
print("\n")
print(correlation)

if correlation >= 0.7:
  print("Strong positive correlation")
elif correlation < -0.7:
  print("strong negative correlation")
else:
  print("weak correlation")
# Out:
# total sales for each product:
# Product A Sales    31600
# Product B Sales    23800
# Product C Sales    11510
# dtype: int64
#
# average monthly sales:
# Product A Sales    1316.666667
# Product B Sales     991.666667
# Product C Sales     479.583333
# dtype: float64
#
# Sales A: 1900 month 2022-12-31 00:00:00
# Sales B: 1700 month 2022-12-31 00:00:00
# Sales C: 720 month 2022-12-31 00:00:00
#
# change percent of product A is 22.58064516129032 %
# change percent of product B is 61.904761904761905 %
# change percent of product C is 44.0 %
#
#
# 0.954652710589704
# Strong positive correlation
# <ipython-input-29-85110b82012a>:2: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print(sales_df.sum())
# <ipython-input-29-85110b82012a>:5: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   print(sales_df.mean())
